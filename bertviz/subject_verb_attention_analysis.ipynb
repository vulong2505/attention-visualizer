# %% [markdown]
# # Prepare Universal Dependencies Treebank Dataset
#
# We are using the UD English EWT Treebank for our dataset. The corpus comprises 254,820 words and 16,622 sentences, taken from five genres of web media: weblogs, newsgroups, emails, reviews, and Yahoo! answers. HuggingFace has these datasets ready to load using the datasets module.
#
# Documentation for the English UD EWT treebank: https://universaldependencies.org/treebanks/en_ewt/index.html
#
# Aside: Taking a look at the tokens list (for a sentence), it's 1-based indexing because of UD indexing. This is because index 0 refers to the root, so index 1 refers to the first token of the sentence.

# %%
# !pip install datasets
# !pip install conllu
# Out:
# Requirement already satisfied: datasets in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (2.18.0)
# Requirement already satisfied: filelock in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from datasets) (3.13.4)
# Requirement already satisfied: numpy>=1.17 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from datasets) (15.0.2)
# Requirement already satisfied: pyarrow-hotfix in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.2.0,>=2023.1.0 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from fsspec[http]<=2024.2.0,>=2023.1.0->datasets) (2024.2.0)
# Requirement already satisfied: aiohttp in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from datasets) (0.22.2)
# Requirement already satisfied: packaging in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface-hub>=0.19.4->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: conllu in /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages (6.0.0)

# %%
from datasets import load_dataset

# Loading dataset parameters
treebank_name = "en_ewt"
split = None  # Load all three splits: train, test, & validation sets.

# Load UD Treebank
dataset = load_dataset("universal_dependencies", treebank_name, split=split)
# Out:
# /Users/arsalan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/datasets/load.py:1461: FutureWarning: The repository for universal_dependencies contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/universal_dependencies
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(

# %%
import ast


def get_dep_info(dep_str):
    """Convert dependency string representation to tuple"""
    try:
        # literal_eval() for safety and also our information should only be literals.
        dep_list = ast.literal_eval(dep_str)
        if dep_list:
            return dep_list[
                0
            ]  # dep_list looks like [(dependency, head_index)], so we grab the tuple inside the list.
        return ("N/A", 0)
    except:
        return ("N/A", 0)


def extract_subject_verb_pairs(sentence) -> list[dict]:
    """
    Extract subject-verb pairs from a sentence.
    """

    subject_verb_pairs = []
    for i, dep_str in enumerate(sentence["deps"]):
        dep_rel, head = get_dep_info(dep_str)
        if dep_rel == "nsubj" and head > 0:  # Skip when the head points to the root.
            subject_idx = i
            verb_idx = (
                head - 1
            )  # The tokens list uses 1-based indexing, because index 0 is technically the root. That's why we're taking the head index - 1, so we can adjust for the 1-based indexing.

            subject_verb_pairs.append(
                {
                    "subject": sentence["tokens"][subject_idx],
                    "verb": sentence["tokens"][verb_idx],
                    "subject_idx": subject_idx,
                    "verb_idx": verb_idx,
                }
            )

    return subject_verb_pairs

# %%
# Test extract subject-verb pairs for evaluation.
extract = extract_subject_verb_pairs(dataset["train"][0])[0]
subj_idx = extract["subject_idx"]
verb_idx = extract["verb_idx"]

sentence = dataset["train"][0]

# %% [markdown]
# # Load model from Hugging Face
#
# One thing to keep in mind. BERT uses the WordPiece tokenization scheme, which is different than the UD tokenization scheme. Therefore, we need to map BERT's tokenization scheme to the UD scheme so we can properly do evaluation of BERT on the ground truth subject-verb pairs from the UD dataset.

# %%
from transformers import AutoModel, AutoTokenizer

# Load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")
model = AutoModel.from_pretrained("bert-base-cased")

# %% [markdown]
# TODO: Implement BertViz to visualize attention head scores
#
# The code below takes one sentence from the UD dataset and extracts the subject-verb pair from that sentence. Then, it feeds the sentence into BERT so we can perform analysis. Here, we examine the attention weights from layer 7. Since the BERT tokenization scheme breaks words into subwords, we evaluate the BERT tokens by taking the max attention score across all subwords for a particular word. For example, max(attention score of ['run', '##ning']).

# %%
import torch


def get_bert_token_mapping(ud_tokens: list, bert_tokens: list, offset_mapping) -> dict:
    """
    Create mapping between UD tokens and BERT tokens.
    Returns a dict mapping UD token index -> list of BERT token indices.
    """
    # Remove special tokens for mapping calculation
    bert_tokens = bert_tokens[1:-1]  # Remove [CLS] and [SEP]
    offset_mapping = offset_mapping[1:-1]  # Remove special tokens' offsets

    # Join UD tokens with spaces to match original text
    text = " ".join(ud_tokens)

    # Create mapping: UD index -> BERT token indices
    ud_to_bert = {}
    current_ud_idx = 0
    current_char_idx = 0

    # For each UD token, find all BERT tokens that correspond to it
    for ud_idx, ud_token in enumerate(ud_tokens):
        bert_indices = []
        token_start = text.find(ud_token, current_char_idx)
        token_end = token_start + len(ud_token)

        # Find all BERT tokens that overlap with this UD token
        for bert_idx, (start, end) in enumerate(offset_mapping):
            # Check if this BERT token overlaps with current UD token
            if start >= token_start and end <= token_end:
                # +1 to account for [CLS] token
                bert_indices.append(bert_idx + 1)

        ud_to_bert[ud_idx] = bert_indices
        current_char_idx = token_end

    return ud_to_bert

# %%
""" Experiment setup to see how subject-verb pairs within a certain sentence are scored for attention heads at a specified layer. """

# Get a sentence with subject-verb pairs
sentence = dataset["train"][200]  # Change index to get different sentence samples
text = " ".join(sentence["tokens"])
pairs = extract_subject_verb_pairs(sentence)

print(f"Sentence: {text}")
print(f"Subject-verb pairs: {pairs}")

# Tokenize with BERT
encoding = tokenizer(text, return_tensors="pt", return_offsets_mapping=True)
input_ids = encoding["input_ids"]
offset_mapping = encoding["offset_mapping"][0].numpy()  # Remove batch dimension
bert_tokens = tokenizer.convert_ids_to_tokens(input_ids[0])

# Get token mapping
token_mapping = get_bert_token_mapping(sentence["tokens"], bert_tokens, offset_mapping)

print("\nBERT tokenization:", bert_tokens)
print("\nToken mapping:")
for ud_idx, bert_indices in token_mapping.items():
    print(
        f"UD token '{sentence['tokens'][ud_idx]}' -> BERT tokens: {[bert_tokens[i] for i in bert_indices]}"
    )

# Get attention weights
with torch.no_grad():
    outputs = model(input_ids, output_attentions=True)

# Get attention weights from layer 7
layer_idx = 6  # 0-based indexing
attention = outputs.attentions[layer_idx][0]  # Shape: [num_heads, seq_len, seq_len]
# For each attention head, there is a seq_len x seq_len matrix of attention scores.
# The rows are tokens DOING the attending
# The columns are tokens BEING attended to
# Each cell [i,j] shows how much token i pays attention to token j

# Analyze attention for subject-verb pairs with proper token mapping
print("\nAttention analysis for layer 7:")
for pair in pairs:
    subject_bert_indices = token_mapping[pair["subject_idx"]]
    verb_bert_indices = token_mapping[pair["verb_idx"]]

    print(f"\nPair: {pair['subject']} -> {pair['verb']}")
    print(
        f"BERT tokens: {[bert_tokens[i] for i in subject_bert_indices]} -> {[bert_tokens[i] for i in verb_bert_indices]}"
    )

    # For each attention head
    for head in range(attention.size(0)):
        # Get max attention scores across all subword combinations
        scores = []
        for subj_idx in subject_bert_indices:
            for verb_idx in verb_bert_indices:
                scores.append(
                    attention[head, subj_idx, verb_idx].item()
                )  # Asking: In this attention head, how much does the token at subject_idx attend to the token at verb_idx?
        # print(scores)
        max_score = max(
            scores
        )  # There can be multiple scores in the attention matrix corresponding to one word (either subject or the verb) because of how the tokenizer breaks up those words. So we take the max of the scores.

        print(f"Head {head}: {max_score:.3f}")
# Out:
# Sentence: Indeed , given how Bush has rampaged around the world alienating allies and ignoring vital conflicts with the potential to blow back on the US , one might well argue that Edwards knows more now than Bush does .
# Subject-verb pairs: [{'subject': 'Bush', 'verb': 'rampaged', 'subject_idx': 4, 'verb_idx': 6}, {'subject': 'one', 'verb': 'argue', 'subject_idx': 26, 'verb_idx': 29}, {'subject': 'Edwards', 'verb': 'knows', 'subject_idx': 31, 'verb_idx': 32}, {'subject': 'Bush', 'verb': 'does', 'subject_idx': 36, 'verb_idx': 37}]
#
# BERT tokenization: ['[CLS]', 'Indeed', ',', 'given', 'how', 'Bush', 'has', 'ramp', '##aged', 'around', 'the', 'world', 'alien', '##ating', 'allies', 'and', 'ignoring', 'vital', 'conflicts', 'with', 'the', 'potential', 'to', 'blow', 'back', 'on', 'the', 'US', ',', 'one', 'might', 'well', 'argue', 'that', 'Edwards', 'knows', 'more', 'now', 'than', 'Bush', 'does', '.', '[SEP]']
#
# Token mapping:
# UD token 'Indeed' -> BERT tokens: ['Indeed']
# UD token ',' -> BERT tokens: [',']
# UD token 'given' -> BERT tokens: ['given']
# UD token 'how' -> BERT tokens: ['how']
# UD token 'Bush' -> BERT tokens: ['Bush']
# UD token 'has' -> BERT tokens: ['has']
# UD token 'rampaged' -> BERT tokens: ['ramp', '##aged']
# UD token 'around' -> BERT tokens: ['around']
# UD token 'the' -> BERT tokens: ['the']
# UD token 'world' -> BERT tokens: ['world']
# UD token 'alienating' -> BERT tokens: ['alien', '##ating']
# UD token 'allies' -> BERT tokens: ['allies']
# UD token 'and' -> BERT tokens: ['and']
# UD token 'ignoring' -> BERT tokens: ['ignoring']
# UD token 'vital' -> BERT tokens: ['vital']
# UD token 'conflicts' -> BERT tokens: ['conflicts']
# UD token 'with' -> BERT tokens: ['with']
# UD token 'the' -> BERT tokens: ['the']
# UD token 'potential' -> BERT tokens: ['potential']
# UD token 'to' -> BERT tokens: ['to']
# UD token 'blow' -> BERT tokens: ['blow']
# UD token 'back' -> BERT tokens: ['back']
# UD token 'on' -> BERT tokens: ['on']
# UD token 'the' -> BERT tokens: ['the']
# UD token 'US' -> BERT tokens: ['US']
# UD token ',' -> BERT tokens: [',']
# UD token 'one' -> BERT tokens: ['one']
# UD token 'might' -> BERT tokens: ['might']
# UD token 'well' -> BERT tokens: ['well']
# UD token 'argue' -> BERT tokens: ['argue']
# UD token 'that' -> BERT tokens: ['that']
# UD token 'Edwards' -> BERT tokens: ['Edwards']
# UD token 'knows' -> BERT tokens: ['knows']
# UD token 'more' -> BERT tokens: ['more']
# UD token 'now' -> BERT tokens: ['now']
# UD token 'than' -> BERT tokens: ['than']
# UD token 'Bush' -> BERT tokens: ['Bush']
# UD token 'does' -> BERT tokens: ['does']
# UD token '.' -> BERT tokens: ['.']
#
# Attention analysis for layer 7:
#
# Pair: Bush -> rampaged
# BERT tokens: ['Bush'] -> ['ramp', '##aged']
# Head 0: 0.000
# Head 1: 0.001
# Head 2: 0.001
# Head 3: 0.010
# Head 4: 0.002
# Head 5: 0.003
# Head 6: 0.002
# Head 7: 0.070
# Head 8: 0.003
# Head 9: 0.027
# Head 10: 0.002
# Head 11: 0.008
#
# Pair: one -> argue
# BERT tokens: ['one'] -> ['argue']
# Head 0: 0.008
# Head 1: 0.001
# Head 2: 0.002
# Head 3: 0.022
# Head 4: 0.343
# Head 5: 0.006
# Head 6: 0.001
# Head 7: 0.618
# Head 8: 0.183
# Head 9: 0.073
# Head 10: 0.007
# Head 11: 0.024
#
# Pair: Edwards -> knows
# BERT tokens: ['Edwards'] -> ['knows']
# Head 0: 0.003
# Head 1: 0.000
# Head 2: 0.001
# Head 3: 0.001
# Head 4: 0.004
# Head 5: 0.006
# Head 6: 0.001
# Head 7: 0.203
# Head 8: 0.007
# Head 9: 0.354
# Head 10: 0.002
# Head 11: 0.009
#
# Pair: Bush -> does
# BERT tokens: ['Bush'] -> ['does']
# Head 0: 0.000
# Head 1: 0.002
# Head 2: 0.000
# Head 3: 0.002
# Head 4: 0.002
# Head 5: 0.003
# Head 6: 0.001
# Head 7: 0.047
# Head 8: 0.003
# Head 9: 0.867
# Head 10: 0.011
# Head 11: 0.004

# %%
# from neuron_view import show

# show(
#     model,
#     "bert",
#     tokenizer,
#     "Indeed , given how Bush has rampaged around the world alienating allies and ignoring vital conflicts with the potential to blow back on the US , one might well argue that Edwards knows more now than Bush does.",
#     "Indeed , given how Bush has rampaged around the world alienating allies and ignoring vital conflicts with the potential to blow back on the US , one might well argue that Edwards knows more now than Bush does.",
#     layer=1,
#     head=1,
# )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 from neuron_view import show
# ----> 3 show(
#       4     model,
#       5     "bert",
#       6     tokenizer,
#       7     "Indeed , given how Bush has rampaged around the world alienating allies and ignoring vital conflicts with the potential to blow back on the US , one might well argue that Edwards knows more now than Bush does.",
#       8     "Indeed , given how Bush has rampaged around the world alienating allies and ignoring vital conflicts with the potential to blow back on the US , one might well argue that Edwards knows more now than Bush does.",
#       9     layer=1,
#      10     head=1,
#      11 )
#
# File ~/Desktop/GWU/GCS/Fall 24/CSCI-6515/FinalProject/bertviz/neuron_view.py:68, in show(model, model_type, tokenizer, sentence_a, sentence_b, display_mode, layer, head, html_action)
#      55 vis_html = f"""
#      56     <div id={vis_id} style="padding:8px;font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#      57       <span style="user-select:none">
#    (...)
#      63     </div>
#      64  """
#      66 __location__ = os.path.realpath(
#      67     os.path.join(os.getcwd(), os.path.dirname(__file__)))
# ---> 68 attn_data = get_attention(model, model_type, tokenizer, sentence_a, sentence_b, include_queries_and_keys=True)
#      69 if model_type == 'gpt2':
#      70     bidirectional = False
#
# File ~/Desktop/GWU/GCS/Fall 24/CSCI-6515/FinalProject/bertviz/neuron_view.py:186, in get_attention(model, model_type, tokenizer, sentence_a, sentence_b, include_queries_and_keys)
#     183     slice_b = slice(len(tokens_a), len(tokens_a) + len(tokens_b))  # Position corresponding to sentence B in input
#     184 for layer, attn_data in enumerate(attn_data_list):
#     185     # Process attention
# --> 186     attn = attn_data['attn'][0]  # assume batch_size=1; shape = [num_heads, source_seq_len, target_seq_len]
#     187     attn_dict['all'].append(attn.tolist())
#     188     if is_sentence_pair:
#
# IndexError: too many indices for tensor of dimension 1

# %%
# from bertviz import head_view, model_view
from transformers import BertTokenizer, BertModel

model_version = "bert-base-cased"
model = BertModel.from_pretrained(model_version, output_attentions=True)
tokenizer = BertTokenizer.from_pretrained(model_version)

sentence_a = "Indeed , given how Bush has rampaged around the world alienating allies and ignoring vital conflicts with the potential to blow back on the US , one might well argue that Edwards knows more now than Bush does."
sentence_b = "Indeed , given how Bush has rampaged around the world alienating allies and ignoring vital conflicts with the potential to blow back on the US , one might well argue that Edwards knows more now than Bush does."

inputs = tokenizer.encode_plus(sentence_a, sentence_b, return_tensors="pt")
input_ids = inputs["input_ids"]
token_type_ids = inputs["token_type_ids"]

outputs2 = model(input_ids, token_type_ids=token_type_ids)
attention = outputs2["attentions"]

print(token_type_ids[0].tolist().index(1))
sentence_b_start = token_type_ids[0].tolist().index(1)
input_id_list = input_ids[0].tolist()  # Batch index 0
tokens = tokenizer.convert_ids_to_tokens(input_id_list)
# Out:
# 43

# %%
from head_view import head_view

html_obj = head_view(attention, tokens, sentence_b_start, html_action="return")
with open("testhtml.html", "w") as f:
    f.write(html_obj.data)
